# %% [markdown]
# # part of speech tagging
# process to label/ tag each word in sentence with grammatical group such as noun, pronoun etc

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
sample = """Recognizing, searching and retrieving more forms of words returns more results. When a form of a word is recognized it can make it possible to return search results that otherwise might have been missed. That additional information retrieved is why stemming is integral to search queries and information retrieval.

When a new word is found, it can present new research opportunities. Often, the best results can be attained by using the basic morphological form of the word: the lemma. To find the lemma, stemming is performed by an individual or an algorithm, which may be used by an AI system. Stemming uses a number of approaches to reduce a word to its base from whatever inflected form is encountered.

It can be simple to develop a stemming algorithm. Some simple algorithms will simply strip recognized prefixes and suffixes. However, these simple algorithms are prone to error. For example, an error can reduce words like laziness to lazi  instead of lazy. Such algorithms may also have difficulty with terms whose inflectional forms don't perfectly mirror the lemma such as with saw and see."""

# %%
word_token = word_tokenize(sample)

# %%
print(word_token)
# Out:
# ['Recognizing', ',', 'searching', 'and', 'retrieving', 'more', 'forms', 'of', 'words', 'returns', 'more', 'results', '.', 'When', 'a', 'form', 'of', 'a', 'word', 'is', 'recognized', 'it', 'can', 'make', 'it', 'possible', 'to', 'return', 'search', 'results', 'that', 'otherwise', 'might', 'have', 'been', 'missed', '.', 'That', 'additional', 'information', 'retrieved', 'is', 'why', 'stemming', 'is', 'integral', 'to', 'search', 'queries', 'and', 'information', 'retrieval', '.', 'When', 'a', 'new', 'word', 'is', 'found', ',', 'it', 'can', 'present', 'new', 'research', 'opportunities', '.', 'Often', ',', 'the', 'best', 'results', 'can', 'be', 'attained', 'by', 'using', 'the', 'basic', 'morphological', 'form', 'of', 'the', 'word', ':', 'the', 'lemma', '.', 'To', 'find', 'the', 'lemma', ',', 'stemming', 'is', 'performed', 'by', 'an', 'individual', 'or', 'an', 'algorithm', ',', 'which', 'may', 'be', 'used', 'by', 'an', 'AI', 'system', '.', 'Stemming', 'uses', 'a', 'number', 'of', 'approaches', 'to', 'reduce', 'a', 'word', 'to', 'its', 'base', 'from', 'whatever', 'inflected', 'form', 'is', 'encountered', '.', 'It', 'can', 'be', 'simple', 'to', 'develop', 'a', 'stemming', 'algorithm', '.', 'Some', 'simple', 'algorithms', 'will', 'simply', 'strip', 'recognized', 'prefixes', 'and', 'suffixes', '.', 'However', ',', 'these', 'simple', 'algorithms', 'are', 'prone', 'to', 'error', '.', 'For', 'example', ',', 'an', 'error', 'can', 'reduce', 'words', 'like', 'laziness', 'to', 'lazi', 'instead', 'of', 'lazy', '.', 'Such', 'algorithms', 'may', 'also', 'have', 'difficulty', 'with', 'terms', 'whose', 'inflectional', 'forms', 'do', "n't", 'perfectly', 'mirror', 'the', 'lemma', 'such', 'as', 'with', 'saw', 'and', 'see', '.']

# %%
nltk.pos_tag(word_token)
# Out:
# [('Recognizing', 'VBG'),
#  (',', ','),
#  ('searching', 'VBG'),
#  ('and', 'CC'),
#  ('retrieving', 'VBG'),
#  ('more', 'JJR'),
#  ('forms', 'NNS'),
#  ('of', 'IN'),
#  ('words', 'NNS'),
#  ('returns', 'NNS'),
#  ('more', 'JJR'),
#  ('results', 'NNS'),
#  ('.', '.'),
#  ('When', 'WRB'),
#  ('a', 'DT'),
#  ('form', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('word', 'NN'),
#  ('is', 'VBZ'),
#  ('recognized', 'VBN'),
#  ('it', 'PRP'),
#  ('can', 'MD'),
#  ('make', 'VB'),
#  ('it', 'PRP'),
#  ('possible', 'JJ'),
#  ('to', 'TO'),
#  ('return', 'VB'),
#  ('search', 'NN'),
#  ('results', 'NNS'),
#  ('that', 'WDT'),
#  ('otherwise', 'RB'),
#  ('might', 'MD'),
#  ('have', 'VB'),
#  ('been', 'VBN'),
#  ('missed', 'VBN'),
#  ('.', '.'),
#  ('That', 'DT'),
#  ('additional', 'JJ'),
#  ('information', 'NN'),
#  ('retrieved', 'VBD'),
#  ('is', 'VBZ'),
#  ('why', 'WRB'),
#  ('stemming', 'VBG'),
#  ('is', 'VBZ'),
#  ('integral', 'JJ'),
#  ('to', 'TO'),
#  ('search', 'VB'),
#  ('queries', 'NNS'),
#  ('and', 'CC'),
#  ('information', 'NN'),
#  ('retrieval', 'NN'),
#  ('.', '.'),
#  ('When', 'WRB'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('word', 'NN'),
#  ('is', 'VBZ'),
#  ('found', 'VBN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('can', 'MD'),
#  ('present', 'VB'),
#  ('new', 'JJ'),
#  ('research', 'NN'),
#  ('opportunities', 'NNS'),
#  ('.', '.'),
#  ('Often', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('results', 'NNS'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('attained', 'VBN'),
#  ('by', 'IN'),
#  ('using', 'VBG'),
#  ('the', 'DT'),
#  ('basic', 'JJ'),
#  ('morphological', 'JJ'),
#  ('form', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('word', 'NN'),
#  (':', ':'),
#  ('the', 'DT'),
#  ('lemma', 'NN'),
#  ('.', '.'),
#  ('To', 'TO'),
#  ('find', 'VB'),
#  ('the', 'DT'),
#  ('lemma', 'NN'),
#  (',', ','),
#  ('stemming', 'VBG'),
#  ('is', 'VBZ'),
#  ('performed', 'VBN'),
#  ('by', 'IN'),
#  ('an', 'DT'),
#  ('individual', 'NN'),
#  ('or', 'CC'),
#  ('an', 'DT'),
#  ('algorithm', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('used', 'VBN'),
#  ('by', 'IN'),
#  ('an', 'DT'),
#  ('AI', 'NNP'),
#  ('system', 'NN'),
#  ('.', '.'),
#  ('Stemming', 'VBG'),
#  ('uses', 'VBZ'),
#  ('a', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('approaches', 'NNS'),
#  ('to', 'TO'),
#  ('reduce', 'VB'),
#  ('a', 'DT'),
#  ('word', 'NN'),
#  ('to', 'TO'),
#  ('its', 'PRP$'),
#  ('base', 'NN'),
#  ('from', 'IN'),
#  ('whatever', 'WDT'),
#  ('inflected', 'JJ'),
#  ('form', 'NN'),
#  ('is', 'VBZ'),
#  ('encountered', 'VBN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('simple', 'JJ'),
#  ('to', 'TO'),
#  ('develop', 'VB'),
#  ('a', 'DT'),
#  ('stemming', 'NN'),
#  ('algorithm', 'NN'),
#  ('.', '.'),
#  ('Some', 'DT'),
#  ('simple', 'JJ'),
#  ('algorithms', 'NNS'),
#  ('will', 'MD'),
#  ('simply', 'RB'),
#  ('strip', 'VB'),
#  ('recognized', 'VBN'),
#  ('prefixes', 'NNS'),
#  ('and', 'CC'),
#  ('suffixes', 'NNS'),
#  ('.', '.'),
#  ('However', 'RB'),
#  (',', ','),
#  ('these', 'DT'),
#  ('simple', 'JJ'),
#  ('algorithms', 'NNS'),
#  ('are', 'VBP'),
#  ('prone', 'JJ'),
#  ('to', 'TO'),
#  ('error', 'VB'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('example', 'NN'),
#  (',', ','),
#  ('an', 'DT'),
#  ('error', 'NN'),
#  ('can', 'MD'),
#  ('reduce', 'VB'),
#  ('words', 'NNS'),
#  ('like', 'IN'),
#  ('laziness', 'NN'),
#  ('to', 'TO'),
#  ('lazi', 'VB'),
#  ('instead', 'RB'),
#  ('of', 'IN'),
#  ('lazy', 'JJ'),
#  ('.', '.'),
#  ('Such', 'JJ'),
#  ('algorithms', 'NN'),
#  ('may', 'MD'),
#  ('also', 'RB'),
#  ('have', 'VB'),
#  ('difficulty', 'NN'),
#  ('with', 'IN'),
#  ('terms', 'NNS'),
#  ('whose', 'WP$'),
#  ('inflectional', 'JJ'),
#  ('forms', 'NNS'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('perfectly', 'RB'),
#  ('mirror', 'VB'),
#  ('the', 'DT'),
#  ('lemma', 'NN'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('with', 'IN'),
#  ('saw', 'NN'),
#  ('and', 'CC'),
#  ('see', 'NN'),
#  ('.', '.')]
